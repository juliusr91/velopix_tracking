# %%
import csv
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scipy.optimize as sp

# %%
general_results = pd.DataFrame(pd.read_csv("GeneralMeasure-030518_5runs_per_file.csv"))

# %%
print(general_results.mean())
print(general_results.min())
print(general_results.max())
print(general_results.std())
# Out:
# CA                                      61.117999
# Total Hits in Event                   2422.100000
# Maximum number of Hits in a Sensor      65.400000
# dtype: float64
# CA                                      2.14042
# Total Hits in Event                   775.00000
# Maximum number of Hits in a Sensor     28.00000
# dtype: float64
# CA                                     248.464087
# Total Hits in Event                   4352.000000
# Maximum number of Hits in a Sensor     119.000000
# dtype: float64
# CA                                      64.001947
# Total Hits in Event                   1059.114368
# Maximum number of Hits in a Sensor      25.309626
# dtype: float64

# %%
plt.scatter(x=general_results["Total Hits in Event"], y=general_results["CA"])
plt.xlabel("Number of Hits per Event")
plt.ylabel("Runtime (Seconds)")
plt.title("Runtime (Seconds) vs Number of Hits")
plt.savefig("/home/julius/Projects/MasterThesis-Tex/Images/Chapter5/runtimeHitsScatter.png", dpi=500)

# %%
plt.scatter(x=general_results["Maximum number of Hits in a Sensor"], y=general_results["CA"])

# %%
def curve_fit(x,a,b):
    return (a*b**(x))

# %%
popt, pcurv = sp.curve_fit(xdata=general_results["Total Hits in Event"], ydata=general_results["CA"], f=curve_fit)

# %%
xdata=general_results["Total Hits in Event"].unique()
xdata= np.sort(xdata)
ydata=curve_fit(xdata, *popt)

# %%
handle1 = plt.plot(xdata, ydata, '--g', label='Runtime Prediction Model')
handle2 = plt.scatter(x=general_results["Total Hits in Event"], y=general_results["CA"], label='Original Data')
plt.xlabel("Number of Hits per Event")
plt.ylabel("Runtime (Seconds)")
plt.title("Runtime Prediction Model vs. Actual Data")
plt.legend()
plt.savefig("/home/julius/Projects/MasterThesis-Tex/Images/Chapter5/ExponentialModelPython.png", dpi=500)

# %% [markdown]
# # Detailed Measure

# %%
results = pd.DataFrame(pd.read_csv("DetailedMeasure-030518_5runs_per_file.csv"))

# %%
print(results.mean(axis=0))
print(results.min(axis=0))
print(results.max(axis=0))
print(results.std(axis=0))
# Out:
# Doublet Creation                         0.959302
# Neighbour search                        57.548154
# CA                                       1.236328
# Extract Possible Tracks                  1.660354
# Remove Short                             0.001644
# Remove Ghost and Clones                  0.324627
# Full Time                               61.730884
# Total Hits in Event                   2422.100000
# Maximum number of Hits in a Sensor      65.400000
# dtype: float64
# Doublet Creation                        0.076521
# Neighbour search                        1.713438
# CA                                      0.089174
# Extract Possible Tracks                 0.251962
# Remove Short                            0.000163
# Remove Ghost and Clones                 0.012597
# Full Time                               2.162797
# Total Hits in Event                   775.000000
# Maximum number of Hits in a Sensor     28.000000
# dtype: float64
# Doublet Creation                         2.759221
# Neighbour search                       237.544709
# CA                                       3.568091
# Extract Possible Tracks                  4.802979
# Remove Short                             0.006043
# Remove Ghost and Clones                  1.449015
# Full Time                              250.038746
# Total Hits in Event                   4352.000000
# Maximum number of Hits in a Sensor     119.000000
# dtype: float64
# Doublet Creation                         0.734823
# Neighbour search                        61.677837
# CA                                       0.946690
# Extract Possible Tracks                  1.046725
# Remove Short                             0.001356
# Remove Ghost and Clones                  0.352281
# Full Time                               64.674053
# Total Hits in Event                   1059.114368
# Maximum number of Hits in a Sensor      25.309626
# dtype: float64

# %%
plt.scatter(results["Total Hits in Event"], results["Full Time"])

# %%
plt.scatter(results["Maximum number of Hits in a Sensor"], results["Full Time"])

# %%
plt.scatter(results["Total Hits in Event"], results["Neighbour search"])

# %%
plt.scatter(results["Maximum number of Hits in a Sensor"], results["Neighbour search"])

# %%
plt.scatter(results["Total Hits in Event"], results["Extract Possible Tracks"])

# %%
plt.scatter(results["Maximum number of Hits in a Sensor"], results["Extract Possible Tracks"])

# %%
plt.scatter(results["Full Time"], results["Extract Possible Tracks"])

# %%
results.corr()
# Out:
#                                     Doublet Creation  Neighbour search  \
# Doublet Creation                            1.000000          0.977499
# Neighbour search                            0.977499          1.000000
# CA                                          0.984572          0.974763
# Extract Possible Tracks                     0.959378          0.956035
# Remove Short                                0.985886          0.989095
# Remove Ghost and Clones                     0.972435          0.994553
# Full Time                                   0.978835          0.999961
# Total Hits in Event                         0.977860          0.919910
# Maximum number of Hits in a Sensor          0.971212          0.928496
#
#                                           CA  Extract Possible Tracks  \
# Doublet Creation                    0.984572                 0.959378
# Neighbour search                    0.974763                 0.956035
# CA                                  1.000000                 0.971798
# Extract Possible Tracks             0.971798                 1.000000
# Remove Short                        0.981698                 0.966427
# Remove Ghost and Clones             0.966501                 0.957972
# Full Time                           0.976445                 0.958295
# Total Hits in Event                 0.964978                 0.933206
# Maximum number of Hits in a Sensor  0.963013                 0.933999
#
#                                     Remove Short  Remove Ghost and Clones  \
# Doublet Creation                        0.985886                 0.972435
# Neighbour search                        0.989095                 0.994553
# CA                                      0.981698                 0.966501
# Extract Possible Tracks                 0.966427                 0.957972
# Remove Short                            1.000000                 0.991449
# Remove Ghost and Clones                 0.991449                 1.000000
# Full Time                               0.989909                 0.994648
# Total Hits in Event                     0.944966                 0.911209
# Maximum number of Hits in a Sensor      0.946151                 0.913818
#
#                                     Full Time  Total Hits in Event  \
# Doublet Creation                     0.978835             0.977860
# Neighbour search                     0.999961             0.919910
# CA                                   0.976445             0.964978
# Extract Possible Tracks              0.958295             0.933206
# Remove Short                         0.989909             0.944966
# Remove Ghost and Clones              0.994648             0.911209
# Full Time                            1.000000             0.922618
# Total Hits in Event                  0.922618             1.000000
# Maximum number of Hits in a Sensor   0.930729             0.984476
#
#                                     Maximum number of Hits in a Sensor
# Doublet Creation                                              0.971212
# Neighbour search                                              0.928496
# CA                                                            0.963013
# Extract Possible Tracks                                       0.933999
# Remove Short                                                  0.946151
# Remove Ghost and Clones                                       0.913818
# Full Time                                                     0.930729
# Total Hits in Event                                           0.984476
# Maximum number of Hits in a Sensor                            1.000000
