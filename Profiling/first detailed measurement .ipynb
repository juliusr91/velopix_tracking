# %%
import csv
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
results = pd.DataFrame(pd.read_csv("FirstDetailedMeasurement-300318_5runs_per_file.csv"))

# %%
print(results.mean(axis=0))
print(results.min(axis=0))
print(results.max(axis=0))
print(results.std(axis=0))
# Out:
# Doublet Creation                         0.960404
# Neighbour search                        56.599005
# CA                                       1.375193
# Extract Possible Tracks                 20.512364
# Remove Short                             0.001784
# Remove Ghost and Clones                  0.327809
# Full Time                               79.777107
# Total Hits in Event                   2422.100000
# Maximum number of Hits in a Sensor      65.400000
# dtype: float64
# Doublet Creation                        0.075314
# Neighbour search                        1.685440
# CA                                      0.096370
# Extract Possible Tracks                 1.436600
# Remove Short                            0.000183
# Remove Ghost and Clones                 0.012732
# Full Time                               3.308012
# Total Hits in Event                   775.000000
# Maximum number of Hits in a Sensor     28.000000
# dtype: float64
# Doublet Creation                         2.737579
# Neighbour search                       233.288848
# CA                                      15.644067
# Extract Possible Tracks                 49.237338
# Remove Short                             0.008202
# Remove Ghost and Clones                  1.517838
# Full Time                              285.152332
# Total Hits in Event                   4352.000000
# Maximum number of Hits in a Sensor     119.000000
# dtype: float64
# Doublet Creation                         0.732558
# Neighbour search                        60.894034
# CA                                       1.541984
# Extract Possible Tracks                 13.034900
# Remove Short                             0.001463
# Remove Ghost and Clones                  0.355587
# Full Time                               69.441280
# Total Hits in Event                   1059.114368
# Maximum number of Hits in a Sensor      25.309626
# dtype: float64

# %%
plt.scatter(results["Total Hits in Event"], results["Full Time"])

# %%
plt.scatter(results["Maximum number of Hits in a Sensor"], results["Full Time"])

# %%
plt.scatter(results["Total Hits in Event"], results["Neighbour search"])

# %%
plt.scatter(results["Maximum number of Hits in a Sensor"], results["Neighbour search"])

# %%
plt.scatter(results["Total Hits in Event"], results["Extract Possible Tracks"])

# %%
plt.scatter(results["Maximum number of Hits in a Sensor"], results["Extract Possible Tracks"])

# %%
plt.scatter(results["Full Time"], results["Extract Possible Tracks"])

# %%
results.corr()
# Out:
#                                     Doublet Creation  Neighbour search  \
# Doublet Creation                            1.000000          0.975086
# Neighbour search                            0.975086          1.000000
# CA                                          0.710484          0.703798
# Extract Possible Tracks                     0.457435          0.408866
# Remove Short                                0.967960          0.979985
# Remove Ghost and Clones                     0.968097          0.994842
# Full Time                                   0.972239          0.984695
# Total Hits in Event                         0.978105          0.917258
# Maximum number of Hits in a Sensor          0.974324          0.926793
#
#                                           CA  Extract Possible Tracks  \
# Doublet Creation                    0.710484                 0.457435
# Neighbour search                    0.703798                 0.408866
# CA                                  1.000000                 0.346146
# Extract Possible Tracks             0.346146                 1.000000
# Remove Short                        0.716946                 0.474622
# Remove Ghost and Clones             0.705380                 0.429355
# Full Time                           0.715476                 0.560974
# Total Hits in Event                 0.695779                 0.497005
# Maximum number of Hits in a Sensor  0.694352                 0.464464
#
#                                     Remove Short  Remove Ghost and Clones  \
# Doublet Creation                        0.967960                 0.968097
# Neighbour search                        0.979985                 0.994842
# CA                                      0.716946                 0.705380
# Extract Possible Tracks                 0.474622                 0.429355
# Remove Short                            1.000000                 0.987407
# Remove Ghost and Clones                 0.987407                 1.000000
# Full Time                               0.979666                 0.984006
# Total Hits in Event                     0.926917                 0.910169
# Maximum number of Hits in a Sensor      0.931933                 0.913861
#
#                                     Full Time  Total Hits in Event  \
# Doublet Creation                     0.972239             0.978105
# Neighbour search                     0.984695             0.917258
# CA                                   0.715476             0.695779
# Extract Possible Tracks              0.560974             0.497005
# Remove Short                         0.979666             0.926917
# Remove Ghost and Clones              0.984006             0.910169
# Full Time                            1.000000             0.928102
# Total Hits in Event                  0.928102             1.000000
# Maximum number of Hits in a Sensor   0.930302             0.984476
#
#                                     Maximum number of Hits in a Sensor
# Doublet Creation                                              0.974324
# Neighbour search                                              0.926793
# CA                                                            0.694352
# Extract Possible Tracks                                       0.464464
# Remove Short                                                  0.931933
# Remove Ghost and Clones                                       0.913861
# Full Time                                                     0.930302
# Total Hits in Event                                           0.984476
# Maximum number of Hits in a Sensor                            1.000000
